# %%
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
#compare algorithms
#Import libraries
import warnings
warnings.filterwarnings('ignore')
from pandas import read_csv
from matplotlib import pyplot
#ML model
from sklearn.model_selection import KFold, cross_val_score
#ML Algorithm(classifier,model)
'''
Linear-Algorithms
'''
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
'''
Non-Linear-Algorithms
'''

from sklearn.svm import SVC
from sklearn.metrics import(
confusion_matrix,
classification_report,
precision_score,
accuracy_score,
roc_auc_score)
# Load CSW using Pandas
from pandas import read_csv
filename = 'Refuge_.csv'
data = read_csv(filename)
array = data.values
X = array[ : , 0:-1]
Y = array[ : , -1]
models = []
models.append(('CB', CatBoostClassifier()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('LB', LGBMClassifier()))
models.append(('SVM', SVC()))
results = []
names = []
score = ['accuracy', 'precision_macro', 'f1_macro']
for name, model in models:
    for metrics in score:
        Kfold = KFold(n_splits=10, random_state=7, shuffle=True)
        cv_results = cross_val_score(model, X, Y,cv=Kfold, scoring=metrics)
        results.append(cv_results)
        names.append(name)
        msg = f'{name} | {metrics} : {cv_results.mean().round(2)*100.0}% ({cv_results.std().round(2)*100.0})%'
        #print(f'{metrics}:{results.mean().round(3)} ({results.std().round(3)})')
        print (msg)
# Out:
# Learning rate set to 0.006652
# 0:	learn: 0.6859934	total: 13.2ms	remaining: 13.1s
# 1:	learn: 0.6788021	total: 23.9ms	remaining: 11.9s
# 2:	learn: 0.6714997	total: 36ms	remaining: 11.9s
# 3:	learn: 0.6643521	total: 46.5ms	remaining: 11.6s
# 4:	learn: 0.6574634	total: 54.4ms	remaining: 10.8s
# 5:	learn: 0.6497590	total: 66.2ms	remaining: 11s
# 6:	learn: 0.6424303	total: 75.5ms	remaining: 10.7s
# 7:	learn: 0.6353810	total: 86.4ms	remaining: 10.7s
# 8:	learn: 0.6294104	total: 94.9ms	remaining: 10.4s
# 9:	learn: 0.6215852	total: 102ms	remaining: 10.1s
# 10:	learn: 0.6154160	total: 109ms	remaining: 9.78s
# 11:	learn: 0.6083464	total: 114ms	remaining: 9.41s
# 12:	learn: 0.6006790	total: 120ms	remaining: 9.1s
# 13:	learn: 0.5944195	total: 127ms	remaining: 8.93s
# 14:	learn: 0.5880269	total: 133ms	remaining: 8.71s
# 15:	learn: 0.5818112	total: 139ms	remaining: 8.56s
# 16:	learn: 0.5761285	total: 145ms	remaining: 8.37s
# 17:	learn: 0.5709270	total: 150ms	remaining: 8.2s
# ...
